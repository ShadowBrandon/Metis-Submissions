# %%
# %%bash
# cd /home/galen/Desktop/audio
# for file in *.mp3;do ffmpeg -i "$file"  -f s16le -acodec pcm_s16le -ar 16000 "${file%.*}".raw;done
# Out:
# ffmpeg version 2.8.6 Copyright (c) 2000-2016 the FFmpeg developers
#   built with gcc 4.8.2 (GCC) 20140120 (Red Hat 4.8.2-15)
#   configuration: --prefix=/home/galen/anaconda3 --disable-doc --enable-shared --enable-static --extra-cflags='-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC -I/home/galen/anaconda3/include' --extra-cxxflags='=-Wall -g -m64 -pipe -O3 -march=x86-64 -fPIC' --extra-libs='-L/home/galen/anaconda3/lib -lz' --enable-pic --enable-gpl --enable-libx264
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# [mp3 @ 0xc183e0] Skipping 0 bytes of junk at 138.
# [mp3 @ 0xc183e0] Estimating duration from bitrate, this may be inaccurate
# ...

# %%
# %%bash
# cd /home/galen/Desktop/audio
# j=1;for i in *.raw; do mv "$i" file"$j".raw; let j=j+1;done

# %% [markdown]
# This notebook takes mp3 files, converts them to linear16 codec and resamples them to 16000. Resampling isn't recommended, but it makes it easy to batch process because you don't need to worry about varying sample rates. Last, the files are renamed to avoid any issues with the cloud.storage API.
